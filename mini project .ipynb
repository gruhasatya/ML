# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/asus/Downloads/gender-classifier.csv", encoding = 'latin-1')

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# 1   10/1/12 13:51  ...  https://pbs.twimg.com/profile_images/539604221...
# 2  11/28/14 11:30  ...  https://pbs.twimg.com/profile_images/657330418...
# 3   6/11/09 22:39  ...  https://pbs.twimg.com/profile_images/259703936...
# 4   4/16/14 13:23  ...  https://pbs.twimg.com/profile_images/564094871...
#
#    retweet_count sidebar_color  \
# 0              0        FFFFFF
# 1              0        C0DEED
# 2              1        C0DEED
# 3              0        C0DEED
# 4              0             0
#
#                                                 text tweet_coord tweet_count  \
# 0  Robbie E Responds To Critics After Win Against...         NaN      110964
# 1  ÛÏIt felt like they were my friends and I was...         NaN        7471
# 2  i absolutely adore when louis starts the songs...         NaN        5617
# 3  Hi @JordanSpieth - Looking at the url - do you...         NaN        1693
# 4  Watching Neighbours on Sky+ catching up with t...         NaN       31462
#
#     tweet_created      tweet_id   tweet_location               user_timezone
# 0  10/26/15 12:40  6.587300e+17  main; @Kan1shk3                     Chennai
# 1  10/26/15 12:40  6.587300e+17              NaN  Eastern Time (US & Canada)
# 2  10/26/15 12:40  6.587300e+17           clcncl                    Belgrade
# 3  10/26/15 12:40  6.587300e+17    Palo Alto, CA  Pacific Time (US & Canada)
# 4  10/26/15 12:40  6.587300e+17              NaN                         NaN
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#         _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 20045  815757572     True      golden                 259               NaN
# 20046  815757681     True      golden                 248               NaN
# 20047  815757830     True      golden                 264               NaN
# 20048  815757921     True      golden                 250               NaN
# 20049  815757985     True      golden                 249               NaN
#
#        gender  gender:confidence profile_yn  profile_yn:confidence  \
# 20045  female             1.0000        yes                    1.0
# 20046    male             1.0000        yes                    1.0
# 20047    male             1.0000        yes                    1.0
# 20048  female             0.8489        yes                    1.0
# 20049  female             1.0000        yes                    1.0
#
#              created  ...                                       profileimage  \
# 20045   8/5/15 21:16  ...  https://pbs.twimg.com/profile_images/656793310...
# 20046  8/15/12 21:17  ...  https://pbs.twimg.com/profile_images/639815429...
# 20047    9/3/12 1:17  ...  https://pbs.twimg.com/profile_images/655473271...
# 20048  11/6/12 23:46  ...  https://pbs.twimg.com/profile_images/657716093...
# 20049  4/14/14 17:22  ...  https://pbs.twimg.com/profile_images/655134724...
#
#        retweet_count sidebar_color  \
# 20045              0        C0DEED
# 20046              0             0
# 20047              0        C0DEED
# 20048              0             0
# 20049              0        C0DEED
#
#                                                     text tweet_coord  \
# 20045  @lookupondeath ...Fine, and I'll drink tea too...         NaN
# 20046  Greg Hardy you a good player and all but don't...         NaN
# 20047  You can miss people and still never want to se...         NaN
# 20048  @bitemyapp i had noticed your tendency to pee ...         NaN
# 20049  I think for my APUSH creative project I'm goin...         NaN
#
#       tweet_count   tweet_created      tweet_id      tweet_location  \
# 20045         783  10/26/15 13:20  6.587400e+17          Verona ªÁ
# 20046       13523  10/26/15 12:40  6.587300e+17     Kansas City, MO
# 20047       26419  10/26/15 13:20  6.587400e+17      Lagos Nigeria
# 20048       56073  10/26/15 12:40  6.587300e+17  Texas Hill Country
# 20049        2922  10/26/15 13:19  6.587400e+17                 NaN
#
#       user_timezone
# 20045           NaN
# 20046           NaN
# 20047           NaN
# 20048           NaN
# 20049           NaN
#
# [5 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# _unit_id                     0
# _golden                      0
# _unit_state                  0
# _trusted_judgments           0
# _last_judgment_at           50
# gender                      97
# gender:confidence           26
# profile_yn                   0
# profile_yn:confidence        0
# created                      0
# description               3744
# fav_number                   0
# gender_gold              20000
# link_color                   0
# name                         0
# profile_yn_gold          20000
# profileimage                 0
# retweet_count                0
# sidebar_color                0
# text                         0
# tweet_coord              19891
# tweet_count                  0
# tweet_created                0
# tweet_id                     0
# tweet_location            7484
# user_timezone             7798
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
#  14  name                   20050 non-null  object
#  15  profile_yn_gold        50 non-null     object
#  16  profileimage           20050 non-null  object
#  17  retweet_count          20050 non-null  int64
#  18  sidebar_color          20050 non-null  object
#  19  text                   20050 non-null  object
#  20  tweet_coord            159 non-null    object
#  21  tweet_count            20050 non-null  int64
#  22  tweet_created          20050 non-null  object
#  23  tweet_id               20050 non-null  float64
#  24  tweet_location         12566 non-null  object
#  25  user_timezone          12252 non-null  object
# dtypes: bool(1), float64(3), int64(5), object(17)
# memory usage: 3.8+ MB

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  gender:confidence  \
# count  2.005000e+04        20050.000000       20024.000000
# mean   8.157294e+08            3.615711           0.882756
# std    6.000801e+03           12.331890           0.191403
# min    8.157192e+08            3.000000           0.000000
# 25%    8.157243e+08            3.000000           0.677800
# 50%    8.157294e+08            3.000000           1.000000
# 75%    8.157345e+08            3.000000           1.000000
# max    8.157580e+08          274.000000           1.000000
#
#        profile_yn:confidence     fav_number  retweet_count   tweet_count  \
# count           20050.000000   20050.000000   20050.000000  2.005000e+04
# mean                0.993221    4382.201646       0.079401  3.892469e+04
# std                 0.047168   12518.575919       2.649751  1.168371e+05
# min                 0.627200       0.000000       0.000000  1.000000e+00
# 25%                 1.000000      11.000000       0.000000  2.398000e+03
# 50%                 1.000000     456.000000       0.000000  1.144150e+04
# 75%                 1.000000    3315.500000       0.000000  4.002750e+04
# max                 1.000000  341621.000000     330.000000  2.680199e+06
#
#            tweet_id
# count  2.005000e+04
# mean   6.587350e+17
# std    5.000124e+12
# min    6.587300e+17
# 25%    6.587300e+17
# 50%    6.587300e+17
# 75%    6.587400e+17
# max    6.587400e+17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20050 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               20050 non-null  int64
#  1   _golden                20050 non-null  bool
#  2   _unit_state            20050 non-null  object
#  3   _trusted_judgments     20050 non-null  int64
#  4   _last_judgment_at      20000 non-null  object
#  5   gender                 19953 non-null  object
#  6   gender:confidence      20024 non-null  float64
#  7   profile_yn             20050 non-null  object
#  8   profile_yn:confidence  20050 non-null  float64
#  9   created                20050 non-null  object
#  10  description            16306 non-null  object
#  11  fav_number             20050 non-null  int64
#  12  gender_gold            50 non-null     object
#  13  link_color             20050 non-null  object
#  14  name                   20050 non-null  object
#  15  profile_yn_gold        50 non-null     object
#  16  profileimage           20050 non-null  object
#  17  retweet_count          20050 non-null  int64
#  18  sidebar_color          20050 non-null  object
#  19  text                   20050 non-null  object
#  20  tweet_coord            159 non-null    object
#  21  tweet_count            20050 non-null  int64
#  22  tweet_created          20050 non-null  object
#  23  tweet_id               20050 non-null  float64
#  24  tweet_location         12566 non-null  object
#  25  user_timezone          12252 non-null  object
# dtypes: bool(1), float64(3), int64(5), object(17)
# memory usage: 3.8+ MB

# %%
df['tweet_coord'].value_counts()
# Out:
# [44.4942, 11.3465]            2
# [27.8428, -82.6995]           2
# [40.798598, -73.971836]       2
# [53.33422016, -2.74855379]    2
# [18.5204, 73.8567]            2
#                              ..
# [-25.7558899, 28.1922625]     1
# [53.9588089, -1.078862]       1
# [33.6189101, -117.9289469]    1
# [31.0835102, -97.6597376]     1
# [40.6084305, -75.4901833]     1
# Name: tweet_coord, Length: 146, dtype: int64

# %%
df.gender.unique()
# Out:
# array(['male', 'female', 'brand', 'unknown', nan], dtype=object)

# %%
df = df.dropna(subset=['gender'])

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# 1   10/1/12 13:51  ...  https://pbs.twimg.com/profile_images/539604221...
# 2  11/28/14 11:30  ...  https://pbs.twimg.com/profile_images/657330418...
# 3   6/11/09 22:39  ...  https://pbs.twimg.com/profile_images/259703936...
# 4   4/16/14 13:23  ...  https://pbs.twimg.com/profile_images/564094871...
#
#    retweet_count sidebar_color  \
# 0              0        FFFFFF
# 1              0        C0DEED
# 2              1        C0DEED
# 3              0        C0DEED
# 4              0             0
#
#                                                 text tweet_coord tweet_count  \
# 0  Robbie E Responds To Critics After Win Against...         NaN      110964
# 1  ÛÏIt felt like they were my friends and I was...         NaN        7471
# 2  i absolutely adore when louis starts the songs...         NaN        5617
# 3  Hi @JordanSpieth - Looking at the url - do you...         NaN        1693
# 4  Watching Neighbours on Sky+ catching up with t...         NaN       31462
#
#     tweet_created      tweet_id   tweet_location               user_timezone
# 0  10/26/15 12:40  6.587300e+17  main; @Kan1shk3                     Chennai
# 1  10/26/15 12:40  6.587300e+17              NaN  Eastern Time (US & Canada)
# 2  10/26/15 12:40  6.587300e+17           clcncl                    Belgrade
# 3  10/26/15 12:40  6.587300e+17    Palo Alto, CA  Pacific Time (US & Canada)
# 4  10/26/15 12:40  6.587300e+17              NaN                         NaN
#
# [5 rows x 26 columns]

# %%
df.gender.unique()
df = df[df.gender != 'unknown']
df = df[df.gender != 'brand']

# %%
df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  815719226    False   finalized                   3    10/26/15 23:24
# 1  815719227    False   finalized                   3    10/26/15 23:30
# 2  815719228    False   finalized                   3    10/26/15 23:33
# 3  815719229    False   finalized                   3    10/26/15 23:10
# 4  815719230    False   finalized                   3     10/27/15 1:15
#
#    gender  gender:confidence profile_yn  profile_yn:confidence  \
# 0    male             1.0000        yes                    1.0
# 1    male             1.0000        yes                    1.0
# 2    male             0.6625        yes                    1.0
# 3    male             1.0000        yes                    1.0
# 4  female             1.0000        yes                    1.0
#
#           created  ...                                       profileimage  \
# 0    12/5/13 1:48  ...  https://pbs.twimg.com/profile_images/414342229...
# 1   10/1/12 13:51  ...  https://pbs.twimg.com/profile_images/539604221...
# 2  11/28/14 11:30  ...  https://pbs.twimg.com/profile_images/657330418...
# 3   6/11/09 22:39  ...  https://pbs.twimg.com/profile_images/259703936...
# 4   4/16/14 13:23  ...  https://pbs.twimg.com/profile_images/564094871...
#
#    retweet_count sidebar_color  \
# 0              0        FFFFFF
# 1              0        C0DEED
# 2              1        C0DEED
# 3              0        C0DEED
# 4              0             0
#
#                                                 text tweet_coord tweet_count  \
# 0  Robbie E Responds To Critics After Win Against...         NaN      110964
# 1  ÛÏIt felt like they were my friends and I was...         NaN        7471
# 2  i absolutely adore when louis starts the songs...         NaN        5617
# 3  Hi @JordanSpieth - Looking at the url - do you...         NaN        1693
# 4  Watching Neighbours on Sky+ catching up with t...         NaN       31462
#
#     tweet_created      tweet_id   tweet_location               user_timezone
# 0  10/26/15 12:40  6.587300e+17  main; @Kan1shk3                     Chennai
# 1  10/26/15 12:40  6.587300e+17              NaN  Eastern Time (US & Canada)
# 2  10/26/15 12:40  6.587300e+17           clcncl                    Belgrade
# 3  10/26/15 12:40  6.587300e+17    Palo Alto, CA  Pacific Time (US & Canada)
# 4  10/26/15 12:40  6.587300e+17              NaN                         NaN
#
# [5 rows x 26 columns]

# %%
df.gender.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df=df[(df['gender:confidence'] >= 1)&(df['profile_yn:confidence'] >= 1)]

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10020 entries, 0 to 20049
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               10020 non-null  int64
#  1   _golden                10020 non-null  bool
#  2   _unit_state            10020 non-null  object
#  3   _trusted_judgments     10020 non-null  int64
#  4   _last_judgment_at      9996 non-null   object
#  5   gender                 10020 non-null  object
#  6   gender:confidence      10020 non-null  float64
#  7   profile_yn             10020 non-null  object
#  8   profile_yn:confidence  10020 non-null  float64
#  9   created                10020 non-null  object
#  10  description            8766 non-null   object
#  11  fav_number             10020 non-null  int64
#  12  gender_gold            24 non-null     object
#  13  link_color             10020 non-null  object
#  14  name                   10020 non-null  object
#  15  profile_yn_gold        24 non-null     object
#  16  profileimage           10020 non-null  object
#  17  retweet_count          10020 non-null  int64
#  18  sidebar_color          10020 non-null  object
#  19  text                   10020 non-null  object
#  20  tweet_coord            62 non-null     object
#  21  tweet_count            10020 non-null  int64
#  22  tweet_created          10020 non-null  object
#  23  tweet_id               10020 non-null  float64
#  24  tweet_location         6891 non-null   object
#  25  user_timezone          6686 non-null   object
# dtypes: bool(1), float64(3), int64(5), object(17)
# memory usage: 2.0+ MB
# _unit_id                    0
# _golden                     0
# _unit_state                 0
# _trusted_judgments          0
# _last_judgment_at          24
# gender                      0
# gender:confidence           0
# profile_yn                  0
# profile_yn:confidence       0
# created                     0
# description              1254
# fav_number                  0
# gender_gold              9996
# link_color                  0
# name                        0
# profile_yn_gold          9996
# profileimage                0
# retweet_count               0
# sidebar_color               0
# text                        0
# tweet_coord              9958
# tweet_count                 0
# tweet_created               0
# tweet_id                    0
# tweet_location           3129
# user_timezone            3334
# dtype: int64

# %%
df=df.drop('gender_gold',axis=1)
df=df.drop('profile_yn_gold',axis=1)
df=df.drop('tweet_coord',axis=1)
df=df.drop('tweet_location',axis=1)
df=df.drop('user_timezone',axis=1)
df=df.drop('_unit_id',axis=1)
df=df.drop('_last_judgment_at',axis=1)
df=df.drop('created',axis=1)
df=df.drop('name',axis=1)
df=df.drop('profileimage',axis=1)
df=df.drop('tweet_created',axis=1)
df=df.drop('_trusted_judgments',axis=1)
df=df.drop('gender:confidence',axis=1)
df=df.drop('profile_yn:confidence',axis=1)
df=df.drop('_golden',axis=1)
df=df.drop('text',axis=1)
df=df.drop('description',axis=1)
df=df.drop('link_color',axis=1)

# %%
df.isnull().sum()
# Out:
# _unit_state      0
# gender           0
# profile_yn       0
# fav_number       0
# retweet_count    0
# sidebar_color    0
# tweet_count      0
# tweet_id         0
# dtype: int64

# %%
dummies= pd.get_dummies(df[['_unit_state','profile_yn','sidebar_color','tweet_id']],drop_first=True)
df=pd.concat([df.drop(['_unit_state','profile_yn','sidebar_color','tweet_id'], axis=1), dummies],axis=1)

# %%
df.gender = df.gender.replace({'male': 1, 'female': 0})

# %%
df
# Out:
#        gender  fav_number  retweet_count  tweet_count      tweet_id  \
# 0           1           0              0       110964  6.587300e+17
# 1           1          68              0         7471  6.587300e+17
# 3           1         202              0         1693  6.587300e+17
# 4           0       37318              0        31462  6.587300e+17
# 5           0        3901              0        20036  6.587300e+17
# ...       ...         ...            ...          ...           ...
# 20044       0         632              0         6669  6.587400e+17
# 20045       0         302              0          783  6.587400e+17
# 20046       1        2513              0        13523  6.587300e+17
# 20047       1          50              0        26419  6.587400e+17
# 20049       0        3348              0         2922  6.587400e+17
#
#        _unit_state_golden  sidebar_color_00090A  sidebar_color_001B5E  \
# 0                       0                     0                     0
# 1                       0                     0                     0
# 3                       0                     0                     0
# 4                       0                     0                     0
# 5                       0                     0                     0
# ...                   ...                   ...                   ...
# 20044                   1                     0                     0
# 20045                   1                     0                     0
# 20046                   1                     0                     0
# 20047                   1                     0                     0
# 20049                   1                     0                     0
#
#        sidebar_color_005A87  sidebar_color_006AFF  ...  sidebar_color_FF4878  \
# 0                         0                     0  ...                     0
# 1                         0                     0  ...                     0
# 3                         0                     0  ...                     0
# 4                         0                     0  ...                     0
# 5                         0                     0  ...                     0
# ...                     ...                   ...  ...                   ...
# 20044                     0                     0  ...                     0
# 20045                     0                     0  ...                     0
# 20046                     0                     0  ...                     0
# 20047                     0                     0  ...                     0
# 20049                     0                     0  ...                     0
#
#        sidebar_color_FF5520  sidebar_color_FF6A00  sidebar_color_FFA6A6  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# 5                         0                     0                     0
# ...                     ...                   ...                   ...
# 20044                     0                     0                     0
# 20045                     0                     0                     0
# 20046                     0                     0                     0
# 20047                     0                     0                     0
# 20049                     0                     0                     0
#
#        sidebar_color_FFB93C  sidebar_color_FFBE3B  sidebar_color_FFD8D6  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# 5                         0                     0                     0
# ...                     ...                   ...                   ...
# 20044                     0                     0                     0
# 20045                     0                     0                     0
# 20046                     0                     0                     0
# 20047                     0                     0                     0
# 20049                     0                     0                     0
#
#        sidebar_color_FFDE00  sidebar_color_FFF8AD  sidebar_color_FFFFFF
# 0                         0                     0                     1
# 1                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# 5                         0                     0                     0
# ...                     ...                   ...                   ...
# 20044                     0                     0                     0
# 20045                     0                     0                     0
# 20046                     0                     0                     0
# 20047                     0                     0                     0
# 20049                     0                     0                     0
#
# [10020 rows x 374 columns]

# %%
import seaborn as sns

# %%
df.corr()
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
sns.distplot(df['gender'],kde=False,bins=40)

# %%
sns.countplot(x='gender',data=df)

# %%
x = df.drop('gender',axis=1).values
y = df['gender'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

accuracies=[]
for k in range(1,101):
  classifier = KNeighborsClassifier(n_neighbors = k)
  classifier.fit(x_train, y_train)
  accuracies.append(classifier.score(x_test, y_test)) 
  
k_list=list(range(1,101)) 
plt.plot(k_list,accuracies)
plt.show()

# %%
classifier = KNeighborsClassifier(n_neighbors =29)
classifier.fit(x_train, y_train)
classifier.score(x_test, y_test)
# Out:
# 0.5768463073852296

# %%
predictions = classifier.predict(x_test) 
from sklearn.metrics import classification_report,confusion_matrix 
print(classification_report(y_test,predictions)) 
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.63      1091
#            1       0.54      0.46      0.50       913
#
#     accuracy                           0.58      2004
#    macro avg       0.57      0.57      0.57      2004
# weighted avg       0.57      0.58      0.57      2004
#
# [[737 354]
#  [494 419]]
